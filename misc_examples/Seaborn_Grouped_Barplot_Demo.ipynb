# %% [markdown]
# <a href="https://colab.research.google.com/github/AvantiShri/colab_notebooks/blob/master/misc_examples/Seaborn_Grouped_Barplot_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import pandas
# model type          seed    callbacktype       auroc
# rc
# siamese
# aug-within
# standard

dataframe = pandas.DataFrame(
 {
     "Model Type": (["rc", "siamese", "aug-within", "standard"]+
                   ["rc", "siamese", "aug-within", "standard"]+
                   ["rc", "siamese", "aug-within", "standard"]+
                   ["rc", "siamese", "aug-within", "standard"]+
                   ["rc", "siamese", "aug-within", "standard"]+
                   ["rc", "siamese", "aug-within", "standard"]),
     "seed": ([100, 100, 100, 100, 200, 200, 200, 200, 300, 300, 300, 300]
             +[100, 100, 100, 100, 200, 200, 200, 200, 300, 300, 300, 300]),
     "Held-out AuROC": [0.9, 0.91, 0.89, 0.88, 0.901, 0.911, 0.891, 0.881, 0.902, 0.912, 0.892, 0.882]+[0.91, 0.92, 0.90, 0.89, 0.911, 0.921, 0.901, 0.891, 0.912, 0.922, 0.902, 0.892],
     "Early Stopping Metric": (["loss", "loss", "loss", "loss"]+
                  ["loss", "loss", "loss", "loss"]+
                  ["loss", "loss", "loss", "loss"]+
                  ["auroc", "auroc", "auroc", "auroc"]+
                  ["auroc", "auroc", "auroc", "auroc"]+
                  ["auroc", "auroc", "auroc", "auroc"])
 }    

)

dataframe
# Out:
#     Model Type  seed  Held-out AuROC Early Stopping Metric
# 0           rc   100           0.900                  loss
# 1      siamese   100           0.910                  loss
# 2   aug-within   100           0.890                  loss
# 3     standard   100           0.880                  loss
# 4           rc   200           0.901                  loss
# 5      siamese   200           0.911                  loss
# 6   aug-within   200           0.891                  loss
# 7     standard   200           0.881                  loss
# 8           rc   300           0.902                  loss
# 9      siamese   300           0.912                  loss
# 10  aug-within   300           0.892                  loss
# 11    standard   300           0.882                  loss
# 12          rc   100           0.910                 auroc
# 13     siamese   100           0.920                 auroc
# 14  aug-within   100           0.900                 auroc
# ...

# %%
import seaborn as sns

from matplotlib import pyplot as plt
sns.barplot(data=dataframe, x="Model Type", y="Held-out AuROC", hue="Early Stopping Metric", ci="sd")
plt.ylim(0.85, 0.93)
plt.show()
